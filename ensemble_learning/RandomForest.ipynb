# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
X,y=make_classification(n_samples=1000, n_features=20, n_informative=2, n_redundant=10, random_state=42,n_classes=2)
df=pd.DataFrame(X, columns=[f'feature_{i}' for i in range(X.shape[1])])
df['target']=y
df
# Out:
#      feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0    -0.496932  -0.339122   0.229146  -0.182569  -1.041103   0.421546
# 1     0.012499   1.007444   0.140096   2.868403  -2.123507  -1.280456
# 2    -0.720212  -1.244486  -0.472291  -1.125655  -0.729670   1.010840
# 3    -0.697364  -0.082698  -0.512911   1.138150   2.297500  -2.072355
# 4    -0.202339  -1.553035  -0.090793  -0.183245   0.664007  -0.326614
# ..         ...        ...        ...        ...        ...        ...
# 995   0.324340   0.145836   0.369973  -0.532725   0.629300  -0.686279
# 996  -1.375634   0.474633  -1.384341  -0.473645  -1.028312  -0.455467
# 997   1.010275  -0.130926   1.180304  -0.044361   0.461680  -0.176112
# 998  -1.207759  -0.380763   0.129067   0.809113  -0.747561  -0.698262
# 999   1.143566  -0.424598  -0.313948   0.106494   0.901661  -0.651443
#
#      feature_6  feature_7  feature_8  feature_9  ...  feature_11  feature_12  \
# 0    -1.015179   0.767666  -1.633819  -0.453981  ...    0.123134    0.977832
# 1    -1.323388   1.420631  -2.725525  -1.325920  ...   -0.054783    1.852633
# 2     0.733484   0.257335   0.028566  -1.091580  ...   -0.505305    0.411076
# 3     2.256809  -1.697290   3.618918   0.993004  ...   -0.278493   -2.161010
# 4     0.521091  -0.465061   0.939386   0.357189  ...   -0.026790   -0.599667
# ..         ...        ...        ...        ...  ...         ...         ...
# 995  -0.547309  -0.238503   0.044630   0.895783  ...    0.400882   -0.370716
# 996   2.674701   0.043886   1.373125  -2.416668  ...   -1.383980    0.267867
# 997  -2.476632   0.228120  -1.652703   1.767843  ...    1.143690    0.121871
# 998  -0.647964   0.535489  -1.107383  -0.369325  ...    0.055260    0.686759
# 999   1.142898  -0.716070   1.629165   0.252043  ...   -0.214601   -0.896912
#
#      feature_13  feature_14  feature_15  feature_16  feature_17  feature_18  \
# 0      0.370061    0.266818    0.153306   -0.320119   -1.179273    0.457806
# 1     -1.254923    0.189480    0.277478   -0.199386   -1.763853    0.937916
# 2      0.449827    3.529055    0.039350    0.652697    0.413948   -0.538790
# 3      1.136191    0.154032   -0.339092    0.716461    2.616592    1.334229
# 4     -1.403559    1.985380   -0.091821    0.127459    0.643637    2.254038
# ..          ...         ...         ...         ...         ...         ...
# 995    0.585299   -1.432671   -0.037956   -0.511153   -0.283798    0.819925
# 996    0.707592    0.244957   -0.021879    1.915874    1.992108    0.408136
# 997    1.128240    0.082987    0.069945   -1.634519   -1.989591   -0.805800
# 998   -1.269465    0.124176    0.106264   -0.180706   -0.777253    0.599103
# 999    0.397638   -1.866701   -0.145199    0.437293    1.247690   -0.307048
#
#      feature_19  target
# 0      0.356006       0
# 1      0.459363       0
# 2     -0.266361       0
# 3     -0.791529       1
# 4     -0.181938       1
# ..          ...     ...
# 995    0.199276       1
# 996   -0.961234       0
# 997    0.887026       1
# 998    0.226718       0
# 999   -0.402463       1
#
# [1000 rows x 21 columns]

# %%
def rowsample(data,percent):
    return data.sample(frac=percent, replace=True, random_state=42)

# %%
def colsample(data,percent):
    cols = data.columns[:-1]  # Exclude the target column
    sampled_cols = np.random.choice(cols, size=int(len(cols) * percent), replace=False)
    return data[sampled_cols.tolist() + ['target']]

# %%
def combined_sampling(df,row_percent,col_percent):
  new_df = rowsample(df,row_percent)
  return colsample(new_df,col_percent)

# %%
df1 = rowsample(df,0.8)
df2=rowsample(df,0.8)
df3=colsample(df,0.8)

# %%
from sklearn.tree import DecisionTreeClassifier
dt1=DecisionTreeClassifier()
dt2=DecisionTreeClassifier()
dt3=DecisionTreeClassifier()

# %%
dt1.fit(df1.iloc[:,:-1],df1.iloc[:,-1])
dt2.fit(df2.iloc[:,:-1],df2.iloc[:,-1])
dt3.fit(df3.iloc[:,:-1],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
test1=np.array(df.iloc[1,:-1]).reshape(1,20)
test1
# Out:
# array([[ 0.01249932,  1.00744397,  0.14009566,  2.86840306, -2.12350652,
#         -1.28045557, -1.32338835,  1.42063115, -2.72552533, -1.3259201 ,
#          0.18471047, -0.05478323,  1.85263278, -1.25492267,  0.18947982,
#          0.27747834, -0.19938562, -1.76385344,  0.93791554,  0.45936344]])

# %%
dt1.predict(test1)
# Out:
# c:\Users\far\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
dt2.predict(test1)
# Out:
# c:\Users\far\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
dt2.predict(test1)
# Out:
# c:\Users\far\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(20,10))
plot_tree(dt1)
# Out:
# [Text(0.6346153846153846, 0.9545454545454546, 'x[4] <= -0.058\ngini = 0.5\nsamples = 800\nvalue = [390.0, 410.0]'),
#  Text(0.4182692307692308, 0.8636363636363636, 'x[2] <= 0.344\ngini = 0.249\nsamples = 418\nvalue = [357.0, 61.0]'),
#  Text(0.5264423076923077, 0.9090909090909092, 'True  '),
#  Text(0.39903846153846156, 0.7727272727272727, 'x[4] <= -0.432\ngini = 0.212\nsamples = 406\nvalue = [357, 49]'),
#  Text(0.20192307692307693, 0.6818181818181818, 'x[1] <= -1.481\ngini = 0.119\nsamples = 345\nvalue = [323, 22]'),
#  Text(0.07692307692307693, 0.5909090909090909, 'x[16] <= -0.337\ngini = 0.386\nsamples = 23\nvalue = [17, 6]'),
#  Text(0.038461538461538464, 0.5, 'x[8] <= -1.39\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.019230769230769232, 0.4090909090909091, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.057692307692307696, 0.4090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11538461538461539, 0.5, 'x[0] <= 1.073\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(0.09615384615384616, 0.4090909090909091, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.1346153846153846, 0.4090909090909091, 'x[8] <= 0.689\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.11538461538461539, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15384615384615385, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3269230769230769, 0.5909090909090909, 'x[3] <= 0.515\ngini = 0.094\nsamples = 322\nvalue = [306.0, 16.0]'),
#  Text(0.25, 0.5, 'x[0] <= 1.384\ngini = 0.044\nsamples = 224\nvalue = [219, 5]'),
#  Text(0.21153846153846154, 0.4090909090909091, 'x[9] <= -0.574\ngini = 0.02\nsamples = 200\nvalue = [198, 2]'),
#  Text(0.19230769230769232, 0.3181818181818182, 'gini = 0.0\nsamples = 171\nvalue = [171, 0]'),
#  Text(0.23076923076923078, 0.3181818181818182, 'x[9] <= -0.548\ngini = 0.128\nsamples = 29\nvalue = [27, 2]'),
#  Text(0.21153846153846154, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.25, 0.22727272727272727, 'x[6] <= -0.705\ngini = 0.069\nsamples = 28\nvalue = [27, 1]'),
#  Text(0.23076923076923078, 0.13636363636363635, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]'),
#  Text(0.2692307692307692, 0.13636363636363635, 'x[11] <= 0.039\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.25, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.28846153846153844, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.28846153846153844, 0.4090909090909091, 'x[18] <= -1.203\ngini = 0.219\nsamples = 24\nvalue = [21, 3]'),
#  Text(0.2692307692307692, 0.3181818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3076923076923077, 0.3181818181818182, 'x[0] <= 1.419\ngini = 0.087\nsamples = 22\nvalue = [21, 1]'),
#  Text(0.28846153846153844, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3269230769230769, 0.22727272727272727, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.40384615384615385, 0.5, 'x[3] <= 0.54\ngini = 0.199\nsamples = 98\nvalue = [87, 11]'),
#  Text(0.36538461538461536, 0.4090909090909091, 'x[8] <= 0.208\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.34615384615384615, 0.3181818181818182, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.38461538461538464, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4423076923076923, 0.4090909090909091, 'x[13] <= -0.951\ngini = 0.104\nsamples = 91\nvalue = [86, 5]'),
#  Text(0.4230769230769231, 0.3181818181818182, 'x[13] <= -1.175\ngini = 0.33\nsamples = 24\nvalue = [19, 5]'),
#  Text(0.40384615384615385, 0.22727272727272727, 'x[5] <= 0.353\ngini = 0.095\nsamples = 20\nvalue = [19, 1]'),
#  Text(0.38461538461538464, 0.13636363636363635, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.4230769230769231, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4423076923076923, 0.22727272727272727, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.46153846153846156, 0.3181818181818182, 'gini = 0.0\nsamples = 67\nvalue = [67, 0]'),
#  Text(0.5961538461538461, 0.6818181818181818, 'x[9] <= 0.128\ngini = 0.493\nsamples = 61\nvalue = [34, 27]'),
#  Text(0.5769230769230769, 0.5909090909090909, 'x[6] <= 0.743\ngini = 0.375\nsamples = 36\nvalue = [9, 27]'),
#  Text(0.5576923076923077, 0.5, 'x[3] <= -0.369\ngini = 0.225\nsamples = 31\nvalue = [4, 27]'),
#  Text(0.5192307692307693, 0.4090909090909091, 'x[18] <= 0.431\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.5, 0.3181818181818182, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5384615384615384, 0.3181818181818182, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5961538461538461, 0.4090909090909091, 'x[14] <= 1.456\ngini = 0.077\nsamples = 25\nvalue = [1, 24]'),
#  Text(0.5769230769230769, 0.3181818181818182, 'gini = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(0.6153846153846154, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5961538461538461, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6153846153846154, 0.5909090909090909, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]'),
#  Text(0.4375, 0.7727272727272727, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.8509615384615384, 0.8636363636363636, 'x[7] <= -0.041\ngini = 0.158\nsamples = 382\nvalue = [33, 349]'),
#  Text(0.7427884615384615, 0.9090909090909092, '  False'),
#  Text(0.7596153846153846, 0.7727272727272727, 'x[6] <= -0.302\ngini = 0.091\nsamples = 333\nvalue = [16, 317]'),
#  Text(0.7403846153846154, 0.6818181818181818, 'x[2] <= 0.419\ngini = 0.225\nsamples = 124\nvalue = [16, 108]'),
#  Text(0.6730769230769231, 0.5909090909090909, 'x[1] <= -0.681\ngini = 0.5\nsamples = 28\nvalue = [14, 14]'),
#  Text(0.6538461538461539, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.6923076923076923, 0.5, 'x[13] <= 0.369\ngini = 0.444\nsamples = 21\nvalue = [14, 7]'),
#  Text(0.6730769230769231, 0.4090909090909091, 'x[8] <= 0.362\ngini = 0.346\nsamples = 18\nvalue = [14, 4]'),
#  Text(0.6538461538461539, 0.3181818181818182, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.6923076923076923, 0.3181818181818182, 'x[6] <= -0.391\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.6730769230769231, 0.22727272727272727, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.7115384615384616, 0.22727272727272727, 'x[18] <= -1.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.6923076923076923, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7307692307692307, 0.13636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7115384615384616, 0.4090909090909091, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8076923076923077, 0.5909090909090909, 'x[14] <= 1.641\ngini = 0.041\nsamples = 96\nvalue = [2, 94]'),
#  Text(0.7692307692307693, 0.5, 'x[0] <= 0.759\ngini = 0.021\nsamples = 93\nvalue = [1, 92]'),
#  Text(0.75, 0.4090909090909091, 'gini = 0.0\nsamples = 73\nvalue = [0, 73]'),
#  Text(0.7884615384615384, 0.4090909090909091, 'x[0] <= 0.951\ngini = 0.095\nsamples = 20\nvalue = [1, 19]'),
#  Text(0.7692307692307693, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8076923076923077, 0.3181818181818182, 'gini = 0.0\nsamples = 19\nvalue = [0, 19]'),
#  Text(0.8461538461538461, 0.5, 'x[10] <= 0.045\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.8269230769230769, 0.4090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8653846153846154, 0.4090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7788461538461539, 0.6818181818181818, 'gini = 0.0\nsamples = 209\nvalue = [0, 209]'),
#  Text(0.9423076923076923, 0.7727272727272727, 'x[16] <= -0.671\ngini = 0.453\nsamples = 49\nvalue = [17.0, 32.0]'),
#  Text(0.9230769230769231, 0.6818181818181818, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(0.9615384615384616, 0.6818181818181818, 'x[16] <= -0.368\ngini = 0.485\nsamples = 29\nvalue = [17, 12]'),
#  Text(0.9423076923076923, 0.5909090909090909, 'x[8] <= -0.682\ngini = 0.308\nsamples = 21\nvalue = [17, 4]'),
#  Text(0.9230769230769231, 0.5, 'x[15] <= 0.049\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.9038461538461539, 0.4090909090909091, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.9423076923076923, 0.4090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9615384615384616, 0.5, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.9807692307692307, 0.5909090909090909, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]')]

# %%
from sklearn.metrics import accuracy_score
print()

# %%
test1=np.array(df.iloc[3,:-1]).reshape(1,20)
print(dt1.predict(test1))
print(dt2.predict(test1))
print(dt3.predict(test1))
# Out:
# [1]
# [1]
# c:\Users\far\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\far\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\far\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 4
#       2 print(dt1.predict(test1))
#       3 print(dt2.predict(test1))
# ----> 4 print(dt3.predict(test1))
#
# File c:\Users\far\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:530, in BaseDecisionTree.predict(self, X, check_input)
#     507 """Predict class or regression value for X.
#     508
#     509 For a classification model, the predicted class for each sample in X is
#    (...)
#     527     The predicted classes, or the predict values.
#     528 """
#     529 check_is_fitted(self)
# --> 530 X = self._validate_X_predict(X, check_input)
#     531 proba = self.tree_.predict(X)
#     532 n_samples = X.shape[0]
#
# File c:\Users\far\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:489, in BaseDecisionTree._validate_X_predict(self, X, check_input)
#     487 else:
#     488     ensure_all_finite = True
# --> 489 X = validate_data(
#     490     self,
#     491     X,
#     492     dtype=DTYPE,
#     493     accept_sparse="csr",
#     494     reset=False,
#     495     ensure_all_finite=ensure_all_finite,
#     496 )
#     497 if issparse(X) and (
#     498     X.indices.dtype != np.intc or X.indptr.dtype != np.intc
#     499 ):
#     500     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File c:\Users\far\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2965, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2962     out = X, y
#    2964 if not no_val_X and check_params.get("ensure_2d", True):
# -> 2965     _check_n_features(_estimator, X, reset=reset)
#    2967 return out
#
# File c:\Users\far\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2829, in _check_n_features(estimator, X, reset)
#    2826     return
#    2828 if n_features != estimator.n_features_in_:
# -> 2829     raise ValueError(
#    2830         f"X has {n_features} features, but {estimator.__class__.__name__} "
#    2831         f"is expecting {estimator.n_features_in_} features as input."
#    2832     )
#
# ValueError: X has 20 features, but DecisionTreeClassifier is expecting 16 features as input.
